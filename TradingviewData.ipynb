# %%
from TradingviewData import TradingViewData, Interval

request = TradingViewData()

# %%
nifty_data = request.get_hist(symbol="TSLA", interval=Interval.min_3, n_bars=1000)

nifty_data
# Out:
#                    Date    Symbol     Open     High      Low    Close  Volume
# 0   2025-06-27 09:18:00  BMV:TSLA  6120.00  6120.00  6120.00  6120.00    24.0
# 1   2025-06-27 09:36:00  BMV:TSLA  6120.00  6120.00  6120.00  6120.00    18.0
# 2   2025-06-27 09:39:00  BMV:TSLA  6110.00  6110.00  6107.00  6107.00    20.0
# 3   2025-06-27 09:45:00  BMV:TSLA  6110.00  6110.00  6107.00  6107.00    19.0
# 4   2025-06-27 10:00:00  BMV:TSLA  6114.55  6114.55  6114.55  6114.55   196.0
# ..                  ...       ...      ...      ...      ...      ...     ...
# 995 2025-07-21 10:36:00  BMV:TSLA  6144.05  6144.05  6139.22  6139.22    10.0
# 996 2025-07-21 10:42:00  BMV:TSLA  6150.00  6150.00  6150.00  6150.00     5.0
# 997 2025-07-21 10:57:00  BMV:TSLA  6144.00  6144.00  6144.00  6144.00    50.0
# 998 2025-07-21 11:06:00  BMV:TSLA  6150.00  6150.00  6150.00  6150.00     6.0
# 999 2025-07-21 11:12:00  BMV:TSLA  6144.00  6150.00  6144.00  6150.00    26.0
#
# [1000 rows x 7 columns]
